# %% [markdown]
# Возьмем популярный датасет 20 Newsgroups, встроенный в пакет sklearn. Датасет состоит из ~20К текстов, классифицированных на 20 категорий. Датасет разбит на train и test. Для загрузки используем модуль fetch_20newsgroups, в параметрах указать, что мета информацию о тексте загружать не нужно:

# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups

newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))

# %% [markdown]
# Выведем список категорий текстов:

# %%
newsgroups_train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %% [markdown]
# Атрибут target хранит номера категорий для текстов из обучающей выборки:

# %%
newsgroups_train.target[:100]
# Out:
# array([ 7,  4,  4,  1, 14, 16, 13,  3,  2,  4,  8, 19,  4, 14,  6,  0,  1,
#         7, 12,  5,  0, 10,  6,  2,  4,  1, 12,  9, 15,  7,  6, 13, 12, 17,
#        18, 10,  8, 11,  8, 16,  9,  4,  3,  9,  9,  4,  4,  8, 12, 14,  5,
#        15,  2, 13, 17, 11,  7, 10,  2, 14, 12,  5,  4,  6,  7,  0, 11, 16,
#         0,  6, 17,  7, 12,  7,  3, 12, 11,  7,  2,  2,  0, 16,  1,  2,  7,
#         3,  2,  1, 10, 12, 12, 17, 12,  2,  8,  8, 18,  5,  0,  1])

# %% [markdown]
# Доступ к самим текстам через атрибут data. Выведем текст и категорию случайного примера из обучающего датасета:

# %%
n = 854
print('Topic = {0}\n'.format(newsgroups_train.target_names[newsgroups_train.target[n]]))
print(newsgroups_train.data[n])
# Out:
# Topic = rec.motorcycles
#
# hey... I'm pretty new to the wonderful world of motorcycles... I just
# bought
# a used 81 Kaw KZ650 CSR from a friend.... I was just wondering what kind of
#
# saddle bags I could get for it (since I know nothing about them)  are there
# bags for the gas tank?  how much would some cost, and how much do they
# hold?
# thanks for your advice!!!  I may be new to riding, but I love it
# already!!!!
# :)

# %% [markdown]
# Представим текст как вектор индикаторов вхождений слов из некоторого словаря в текст. Это простейшая модель BOF.
#
# Сформируем словарь на основе нашего набора текстов. Для этого используем модуль CountVectorizer:

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS

vectorizer = CountVectorizer(lowercase=True, stop_words=ENGLISH_STOP_WORDS,
                             analyzer='word', binary=True, max_df=0.1, min_df=0.00085)
vectorizer.fit(newsgroups_train.data)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.1, max_features=None, min_df=0.00085,
#         ngram_range=(1, 1), preprocessor=None,
#         stop_words=frozenset({'third', 'beyond', 'seems', 'your', 'once', 'con', 'ourselves', 'no', 'too', 'otherwise', 'her', 'whereupon', 'a', 'might', 'detail', 'along', 'elsewhere', 'herself', 'becomes', 'formerly', 'every', 'of', 'have', 'twelve', 'often', 'co', 'whereafter', 'beside', 'besides', 'fift...'either', 'inc', 'less', 'also', 'amount', 'mine', 'see', 'onto', 'without', 'amoungst', 'thereby'}),
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
len(vectorizer.vocabulary_)
# Out:
# 10421

# %% [markdown]
# Проиндексированные слова и их индексы

# %%
vectorizer.vocabulary_
# Out:
# {'wondering': 10254,
#  'enlighten': 3609,
#  'car': 1923,
#  'saw': 8317,
#  'day': 2890,
#  'door': 3317,
#  'sports': 8888,
#  'looked': 5791,
#  'late': 5563,
#  '60s': 546,
#  'early': 3429,
#  '70s': 597,
#  'called': 1877,
#  'doors': 3318,
#  'really': 7751,
#  'small': 8733,
#  'addition': 830,
#  'bumper': 1808,
#  'separate': 8480,
#  'rest': 8030,
#  'body': 1645,
#  'model': 6227,
#  'engine': 3593,
#  'specs': 8851,
#  'years': 10373,
#  'production': 7423,
#  'history': 4719,
#  'info': 5048,
#  'looking': 5792,
#  'mail': 5889,
#  'fair': 3891,
#  'number': 6572,
#  'brave': 1727,
#  'souls': 8806,
#  'upgraded': 9843,
#  'si': 8618,
#  'clock': 2204,
#  'oscillator': 6773,
#  'shared': 8545,
#  'experiences': 3796,
#  'poll': 7197,
#  'send': 8461,
#  'brief': 1748,
#  'message': 6093,
#  'detailing': 3085,
#  'procedure': 7404,
#  'speed': 8857,
#  'cpu': 2711,
#  'rated': 7705,
#  'add': 827,
#  'cards': 1930,
#  'adapters': 824,
#  'heat': 4647,
#  'hour': 4792,
#  'usage': 9861,
#  'floppy': 4083,
#  'disk': 3229,
#  'functionality': 4236,
#  '800': 624,
#  'floppies': 4082,
#  'especially': 3668,
#  'requested': 7977,
#  'days': 2891,
#  'network': 6470,
#  'knowledge': 5496,
#  'base': 1446,
#  'upgrade': 9842,
#  'haven': 4612,
#  'answered': 1073,
#  'folks': 4102,
#  'mac': 5868,
#  'plus': 7167,
#  'finally': 4016,
#  'gave': 4289,
#  'ghost': 4353,
#  'weekend': 10154,
#  'starting': 8947,
#  'life': 5695,
#  '512k': 506,
#  '1985': 206,
#  'market': 5960,
#  'machine': 5870,
#  'bit': 1586,
#  'sooner': 8799,
#  'intended': 5145,
#  'picking': 7073,
#  'powerbook': 7265,
#  '160': 115,
#  'maybe': 6013,
#  '180': 140,
#  'bunch': 1809,
#  'questions': 7627,
#  'hopefully': 4771,
#  'somebody': 8789,
#  'answer': 1072,
#  'anybody': 1081,
#  'dirt': 3181,
#  'round': 8194,
#  'expected': 3786,
#  'heard': 4642,
#  'supposed': 9180,
#  'summer': 9149,
#  'anymore': 1082,
#  'access': 757,
#  'rumors': 8225,
#  'price': 7359,
#  'drops': 3377,
#  'line': 5722,
#  'ones': 6690,
#  'duo': 3403,
#  'went': 10166,
#  'recently': 7777,
#  'impression': 4949,
#  'display': 3237,
#  'probably': 7398,
#  'swing': 9234,
#  'got': 4418,
#  '80mb': 630,
#  '120': 61,
#  'feel': 3968,
#  'better': 1544,
#  'yea': 10369,
#  'looks': 5793,
#  'great': 4466,
#  'store': 9020,
#  'wow': 10292,
#  'opinions': 6715,
#  'worth': 10284,
#  'taking': 9281,
#  'size': 8683,
#  'money': 6256,
#  'hit': 4720,
#  'active': 808,
#  'realize': 7747,
#  'real': 7742,
#  'subjective': 9091,
#  'question': 7623,
#  'played': 7148,
#  'machines': 5871,
#  'computer': 2411,
#  'figured': 3999,
#  'actually': 815,
#  'uses': 9870,
#  'daily': 2844,
#  'prove': 7512,
#  'helpful': 4671,
#  'perform': 6999,
#  'advance': 864,
#  'email': 3528,
#  'll': 5756,
#  'post': 7242,
#  'summary': 9148,
#  'news': 6481,
#  'reading': 7736,
#  'premium': 7317,
#  'finals': 4017,
#  'corner': 2649,
#  'tom': 9522,
#  'willis': 10200,
#  'ecn': 3450,
#  'purdue': 7566,
#  'edu': 3471,
#  'electrical': 3509,
#  'engineering': 3596,
#  'address': 834,
#  'phone': 7056,
#  'information': 5052,
#  'chip': 2095,
#  'article': 1205,
#  'world': 10274,
#  'std': 8973,
#  'com': 2285,
#  'baker': 1417,
#  'understanding': 9783,
#  'errors': 3656,
#  'basically': 1452,
#  'known': 5498,
#  'bugs': 1794,
#  'warning': 10099,
#  'software': 8770,
#  'things': 9439,
#  'checked': 2073,
#  'values': 9923,
#  'aren': 1158,
#  'set': 8506,
#  'till': 9487,
#  'launch': 5573,
#  'fix': 4048,
#  'code': 2242,
#  'possibly': 7241,
#  'introduce': 5202,
#  'tell': 9356,
#  'crew': 2742,
#  'ok': 6676,
#  '213': 259,
#  'ignore': 4884,
#  'course': 2694,
#  'term': 9378,
#  'defined': 2972,
#  'doubt': 3327,
#  'using': 9871,
#  'quote': 7638,
#  'allegedly': 975,
#  'read': 7731,
#  'presenting': 7330,
#  'argument': 1169,
#  'weapons': 10142,
#  'mass': 5983,
#  'destruction': 3081,
#  'commonly': 2331,
#  'understood': 9784,
#  'switching': 9239,
#  'topics': 9538,
#  'point': 7175,
#  'evidently': 3714,
#  'allowed': 985,
#  'later': 5565,
#  'analysis': 1032,
#  'given': 4366,
#  'consider': 2499,
#  'class': 2168,
#  'responded': 8022,
#  'request': 7976,
#  'treatment': 9635,
#  'couldn': 2677,
#  'thank': 9413,
#  'directly': 3176,
#  'bouncing': 1698,
#  'sean': 8392,
#  'sharon': 8550,
#  'thought': 9450,
#  'publicly': 7542,
#  'sure': 9185,
#  'glad': 4373,
#  'accidentally': 764,
#  'rn': 8140,
#  'instead': 5112,
#  'rm': 8139,
#  'trying': 9684,
#  'delete': 2988,
#  'file': 4002,
#  'september': 8487,
#  'hmmm': 4731,
#  'shows': 8611,
#  'scsi': 8380,
#  'controler': 2586,
#  'range': 7687,
#  '5mb': 533,
#  'controller': 2588,
#  '6mb': 587,
#  '10mb': 44,
#  'burst': 1821,
#  'note': 6539,
#  'increase': 4989,
#  'quadra': 7602,
#  'version': 9965,
#  'exist': 3767,
#  'pc': 6964,
#  'mode': 6226,
#  '16': 114,
#  'wide': 10185,
#  'fast': 3927,
#  '12mb': 74,
#  '20mb': 253,
#  '32': 380,
#  '15': 101,
#  '40mb': 450,
#  'data': 2873,
#  'twice': 9711,
#  'esdi': 3666,
#  'correct': 2658,
#  'reach': 7722,
#  '20': 242,
#  'faster': 3928,
#  'ide': 4861,
#  '96': 669,
#  'facts': 3881,
#  'posted': 7245,
#  'newsgroup': 6482,
#  'ibm': 4851,
#  'sheet': 8559,
#  'available': 1353,
#  'ftp': 4222,
#  'sumex': 9143,
#  'aim': 935,
#  'stanford': 8939,
#  '36': 411,
#  '44': 463,
#  'report': 7952,
#  'compare': 2348,
#  'txt': 9718,
#  '161': 117,
#  'problem': 7402,
#  'documented': 3293,
#  'apple': 1109,
#  'said': 8270,
#  'maximum': 6011,
#  'synchronous': 9253,
#  'slower': 8727,
#  'interface': 5166,
#  'driven': 3367,
#  'true': 9673,
#  'win': 10202,
#  'downloaded': 3332,
#  'icons': 4857,
#  'bmp': 1631,
#  'figure': 3998,
#  'change': 2037,
#  'wallpaper': 10086,
#  'help': 4669,
#  'appreciated': 1123,
#  'thanx': 9415,
#  'board': 1637,
#  'year': 10371,
#  'work': 10263,
#  'licensing': 5690,
#  'technologies': 9339,
#  'owners': 6814,
#  'compression': 2402,
#  'technology': 9340,
#  'writing': 10305,
#  'memory': 6073,
#  'lost': 5808,
#  'reference': 7815,
#  'wrong': 10308,
#  'problems': 7403,
#  'hard': 4582,
#  'fault': 3936,
#  'icon': 4856,
#  'usually': 9875,
#  'mentioned': 6079,
#  'freeware': 4198,
#  'expansion': 3782,
#  'utility': 9881,
#  'dd': 2895,
#  'expand': 3779,
#  'compressed': 2401,
#  'unless': 9816,
#  'installed': 5107,
#  'product': 7422,
#  'unlikely': 9818,
#  'holes': 4742,
#  'related': 7868,
#  'fixed': 4049,
#  'sad': 8261,
#  'makes': 5910,
#  'reluctant': 7895,
#  'buy': 1835,
#  'hey': 4690,
#  'competition': 2366,
#  '1978': 197,
#  'runs': 8230,
#  'paint': 6854,
#  'brown': 1772,
#  'orange': 6736,
#  'leaks': 5613,
#  'oil': 6673,
#  'pops': 7210,
#  '1st': 236,
#  'shop': 8588,
#  'trans': 9594,
#  'leak': 5612,
#  'sold': 8775,
#  'bike': 1563,
#  'owner': 6813,
#  'thinking': 9440,
#  '3k': 437,
#  'nice': 6493,
#  'stable': 8917,
#  'axis': 1379,
#  'motors': 6306,
#  'richardson': 8096,
#  'tx': 9717,
#  'org': 6749,
#  'dod': 3295,
#  'yep': 10378,
#  'pretty': 7349,
#  'jew': 5328,
#  'understand': 9781,
#  'jewish': 5329,
#  'jews': 5330,
#  'believe': 1514,
#  'covenant': 2700,
#  'abraham': 725,
#  'moses': 6285,
#  'case': 1953,
#  'moral': 6274,
#  'follow': 4103,
#  'mankind': 5932,
#  'decide': 2919,
#  'boundaries': 1700,
#  'fall': 3899,
#  'believed': 1515,
#  'torah': 9541,
#  'required': 7981,
#  'pharisees': 7038,
#  'ancestors': 1036,
#  'modern': 6235,
#  'judaism': 5379,
#  'interpretation': 5183,
#  'lead': 5602,
#  'morality': 6275,
#  'essence': 3671,
#  'biblical': 1555,
#  'man': 5916,
#  'christian': 2112,
#  'necessarily': 6431,
#  'indicate': 5006,
#  'outside': 6797,
#  'relationship': 7873,
#  'speculate': 8854,
#  'trouble': 9669,
#  'created': 2730,
#  'image': 4904,
#  'means': 6032,
#  'different': 3145,
#  'come': 2297,
#  'conclusion': 2432,
#  'wants': 10092,
#  'script': 8372,
#  'foundation': 4168,
#  'mix': 6211,
#  'living': 5753,
#  'christ': 2111,
#  'example': 3728,
#  'little': 5748,
#  'jesus': 5325,
#  'person': 7020,
#  'recorded': 7792,
#  'followers': 4105,
#  'references': 7817,
#  'historians': 4714,
#  'revelation': 8064,
#  'aside': 1220,
#  'second': 8404,
#  'hand': 4554,
#  'worse': 10281,
#  'attempt': 1299,
#  'christianity': 2113,
#  'initially': 5068,
#  'bible': 1554,
#  'interpret': 5182,
#  'humanity': 4815,
#  'guess': 4507,
#  'faith': 3895,
#  'comes': 2299,
#  'inherent': 5062,
#  'absolute': 730,
#  'multiple': 6344,
#  'codes': 2244,
#  'founded': 4170,
#  'parent': 6891,
#  'child': 2089,
#  'swear': 9226,
#  'assume': 1256,
#  'simply': 8656,
#  'told': 9517,
#  'pub': 7537,
#  'bar': 1435,
#  'children': 2092,
#  'inappropriate': 4963,
#  'quite': 7635,
#  'happy': 4579,
#  'animals': 1053,
#  'analogy': 1030,
#  'hold': 4736,
#  'water': 10121,
#  'knows': 5499,
#  'type': 9720,
#  'incidentally': 4969,
#  'young': 10390,
#  'considers': 2506,
#  'directive': 3175,
#  'gets': 4346,
#  'older': 6681,
#  'david': 2883,
#  'religion': 7892,
#  'description': 3054,
#  'external': 3846,
#  'tank': 9293,
#  'option': 6731,
#  'ssf': 8912,
#  'redesign': 7803,
#  'deleted': 2989,
#  'yo': 10388,
#  'ken': 5433,
#  'let': 5658,
#  'orbiter': 6739,
#  'options': 6733,
#  'list': 5735,
#  'today': 9512,
#  '23': 277,
#  'edition': 3464,
#  'york': 10389,
#  'times': 9492,
#  'reports': 7958,
#  'connor': 2487,
#  'panel': 6869,
#  'proposals': 7485,
#  'dropped': 3375,
#  'giant': 4355,
#  'fuel': 4226,
#  'tanks': 9294,
#  'launching': 5578,
#  'space': 8819,
#  'building': 1797,
#  'station': 8958,
#  'existing': 3772,
#  'shuttle': 8616,
#  'wings': 10212,
#  'tail': 9278,
#  'removed': 7920,
#  'currently': 2809,
#  'considered': 2504,
#  'presented': 7329,
#  'advisory': 879,
#  'meeting': 6057,
#  'yesterday': 10381,
#  'reported': 7953,
#  'low': 5821,
#  'cost': 2673,
#  'modular': 6243,
#  'approach': 1124,
#  'studied': 9076,
#  'team': 9327,
#  'teams': 9328,
#  'jsc': 5375,
#  'larc': 5551,
#  'supporting': 9176,
#  'crystal': 2781,
#  'city': 2150,
#  'lerc': 5652,
#  'reston': 8034,
#  'site': 8675,
#  'locations': 5771,
#  'helping': 4672,
#  'respective': 8018,
#  'activities': 811,
#  'key': 5442,
#  'features': 3956,
#  'bus': 1823,
#  'developed': 3102,
#  'lockheed': 5774,
#  'qualified': 7606,
#  'sts': 9071,
#  'provides': 7521,
#  'propulsion': 7492,
#  'gn': 4389,
#  'communications': 2335,
#  'management': 5919,
#  'air': 938,
#  'force': 4125,
#  'power': 7264,
#  'capability': 1910,
#  'obtained': 6625,
#  'flights': 4076,
#  'solar': 8773,
#  'arrays': 1192,
#  'provide': 7516,
#  'vehicle': 9945,
#  'arrow': 1202,
#  'environment': 3631,
#  'missions': 6196,
#  'utilize': 9882,
#  'source': 8812,
#  '30': 363,
#  'human': 4813,
#  'tended': 9370,
#  'opposed': 6721,
#  'old': 6680,
#  'achieved': 789,
#  'common': 2330,
#  'module': 6245,
#  'modified': 6240,
#  'lab': 5516,
#  'ports': 7227,
#  'added': 828,
#  'international': 5179,
#  'partners': 6916,
#  'labs': 5524,
#  'place': 7117,
#  '60': 540,
#  'esa': 3660,
#  'modules': 6246,
#  'permanent': 7009,
#  'presence': 7325,
#  '3rd': 441,
#  'assured': 1264,
#  'return': 8054,
#  'freedom': 4193,
#  'derived': 3048,
#  'based': 1448,
#  'mike': 6140,
#  'alot': 989,
#  'design': 3061,
#  'love': 5816,
#  'assumes': 1258,
#  'assembly': 1234,
#  'computed': 2410,
#  '51': 503,
#  'inclination': 4971,
#  'orbit': 6737,
#  'build': 1795,
#  'occurs': 6640,
#  'initial': 5066,
#  'research': 7988,
#  'reached': 7723,
#  'transferred': 9599,
#  'visits': 10023,
#  'adopted': 859,
#  'non': 6519,
#  'language': 5548,
#  'deployed': 3036,
#  '10': 27,
#  'keeping': 5428,
#  'supply': 9171,
#  'tolerance': 9518,
#  '14': 88,
#  '2nd': 354,
#  'thermal': 9434,
#  'control': 2585,
#  'radiator': 7663,
#  'finish': 4028,
#  '24': 287,
#  'systems': 9263,
#  'exception': 3734,
#  'major': 5904,
#  'changes': 2039,
#  'reduced': 7807,
#  'prices': 7361,
#  'forsale': 4153,
#  'behalf': 1502,
#  'brother': 1769,
#  'moving': 6321,
#  'moved': 6315,
#  'offer': 6656,
#  'black': 1598,
#  'portable': 7220,
#  'purchased': 7563,
#  '12': 60,
#  'sr': 8907,
#  '1000': 29,
#  'dual': 3392,
#  'cassette': 1957,
#  'player': 7149,
#  'fm': 4094,
#  'band': 1426,
#  'graphics': 4456,
#  'high': 4698,
#  'tape': 9296,
#  'deck': 2926,
#  'sound': 8807,
#  'bet': 1541,
#  '80': 623,
#  '25': 301,
#  'zoom': 10417,
#  'japan': 5308,
#  'includes': 4975,
#  'accessories': 761,
#  '50': 496,
#  '1400': 90,
#  'hair': 4543,
#  'head': 4626,
#  'ask': 1221,
#  'bag': 1414,
#  'leather': 5620,
#  'brand': 1723,
#  'speeds': 8860,
#  'extra': 3848,
#  'angle': 1049,
#  'spray': 8891,
#  'steam': 8979,
#  'dry': 3384,
#  'iron': 5252,
#  'contact': 2540,
#  'reply': 7950,
#  'included': 4974,
#  'reasonable': 7756,
#  'look': 5790,
#  'happened': 4573,
#  'japanese': 5309,
#  'citizens': 2148,
#  'war': 10093,
#  'ii': 4888,
#  'prepared': 7321,
#  'stick': 8998,
#  'concentration': 2419,
#  'camp': 1888,
#  'trial': 9646,
#  'short': 8592,
#  'step': 8986,
#  'nazis': 6411,
#  'originally': 6764,
#  'final': 4015,
#  'solution': 8783,
#  'partly': 6914,
#  'afford': 898,
#  'run': 8226,
#  'camps': 1892,
#  'caused': 1976,
#  'total': 9551,
#  'weren': 10167,
#  'generally': 4310,
#  'died': 3137,
#  'disease': 3224,
#  'certainly': 2012,
#  'tiff': 9483,
#  'works': 10270,
#  'complexity': 2386,
#  'led': 5627,
#  'programs': 7442,
#  'poor': 7204,
#  'writers': 10303,
#  'making': 5911,
#  'bizarre': 1594,
#  'files': 4005,
#  'inability': 4960,
#  'load': 5760,
#  'images': 4906,
#  'save': 8311,
#  'general': 4308,
#  'environments': 3633,
#  'despite': 3076,
#  'fact': 3876,
#  'saying': 8318,
#  'goes': 4403,
#  'worried': 10278,
#  'abuse': 737,
#  'immense': 4916,
#  'unnecessary': 9822,
#  'format': 4144,
#  'words': 10262,
#  'spec': 8836,
#  'page': 6847,
#  'emphasis': 3542,
#  'sort': 8802,
#  'success': 9112,
#  'designed': 3063,
#  'powerful': 7267,
#  'flexible': 4074,
#  'expense': 3791,
#  'simplicity': 8654,
#  'takes': 9280,
#  'effort': 3487,
#  'handle': 4561,
#  'specification': 8845,
#  'application': 1114,
#  'complete': 2381,
#  'job': 5338,
#  'able': 720,
#  'import': 4940,
#  'generating': 4314,
#  'applications': 1115,
#  'program': 7436,
#  'won': 10250,
#  'deal': 2899,
#  'trapped': 9623,
#  'agrees': 926,
#  'reasoning': 7759,
#  'asking': 1223,
#  'kind': 5468,
#  'rates': 7706,
#  'single': 8666,
#  'male': 5913,
#  'drivers': 3369,
#  'paying': 6957,
#  'performance': 7000,
#  'cars': 1948,
#  'replies': 7949,
#  'received': 7771,
#  '27': 323,
#  'close': 2208,
#  '1992': 214,
#  'dodge': 3296,
#  'stealth': 8978,
#  'rt': 8212,
#  'twin': 9712,
#  'turbo': 9697,
#  'tickets': 9479,
#  'accidents': 765,
#  'house': 4794,
#  'taken': 9279,
#  'defensive': 2967,
#  'driving': 3372,
#  'abs': 727,
#  'security': 8420,
#  'alarm': 951,
#  '1500': 103,
#  '500': 497,
#  'state': 8951,
#  'farm': 3921,
#  'insurance': 5127,
#  'additional': 831,
#  '100': 28,
#  '000': 1,
#  'policy': 7189,
#  'standard': 8933,
#  '300': 364,
#  'bought': 1693,
#  'company': 2344,
#  'accident': 762,
#  'ticket': 9478,
#  '11': 46,
#  'quoted': 7639,
#  'hope': 4769,
#  'helps': 4674,
#  'steve': 8994,
#  'university': 9811,
#  '45': 465,
#  'kevin': 5441,
#  'remembered': 7910,
#  'correctly': 2662,
#  'asked': 1222,
#  'similar': 8644,
#  'situation': 8679,
#  'inquiry': 5089,
#  'age': 908,
#  'eagle': 3423,
#  'record': 7791,
#  'clean': 2178,
#  'illinois': 4898,
#  'turn': 9703,
#  '520': 513,
#  'higher': 4699,
#  'rate': 7704,
#  'couple': 2691,
#  'friends': 4212,
#  'pay': 6956,
#  'ins': 5091,
#  'companies': 2343,
#  'lucky': 5836,
#  'dan': 2854,
#  'mot': 6288,
#  'motorola': 6305,
#  'cellular': 1996,
#  'group': 4490,
#  '38': 421,
#  'usa': 9858,
#  'cc': 1983,
#  'live': 5749,
#  'oklahoma': 6678,
#  'drive': 3366,
#  '89': 647,
#  'sc': 8321,
#  'claim': 2160,
#  'negligent': 6443,
#  'stop': 9015,
#  'signs': 8638,
#  'radios': 7668,
#  'violations': 10006,
#  '18': 139,
#  'months': 6268,
#  'going': 4404,
#  '85': 639,
#  '55': 517,
#  'failure': 3888,
#  'clear': 2183,
#  'intersection': 5191,
#  'damn': 2851,
#  'light': 5701,
#  'yellow': 10377,
#  '35': 402,
#  'didn': 3135,
#  'passive': 6930,
#  'liability': 5673,
#  'comprehensive': 2399,
#  'collision': 2271,
#  'roughly': 8193,
#  '1300': 78,
#  '1100': 48,
#  '92': 664,
#  'lx': 5849,
#  'james': 5302,
#  'law': 5579,
#  'center': 2001,
#  'ucs': 9742,
#  'disclaimer': 3205,
#  'engineer': 3594,
#  'play': 7146,
#  'calls': 1880,
#  'thunder': 9475,
#  'bird': 1580,
#  'hell': 4664,
#  'thing': 9438,
#  'killing': 5464,
#  'away': 1371,
#  'gonna': 4409,
#  '61': 547,
#  'experience': 3794,
#  'ago': 920,
#  'interesting': 5163,
#  'owned': 6812,
#  'toyota': 9565,
#  'gt': 4499,
#  'decided': 2920,
#  'gift': 4360,
#  'exotic': 3778,
#  'runners': 8228,
#  'porsche': 7218,
#  '1987': 208,
#  'liked': 5707,
#  'handling': 4565,
#  'appeal': 1099,
#  'personal': 7021,
#  'luxury': 5847,
#  'acceleration': 748,
#  'ready': 7740,
#  'buying': 1838,
#  'impulse': 4959,
#  'agent': 913,
#  'office': 6660,
#  'happen': 4572,
#  'classification': 2172,
#  'slight': 8715,
#  'newer': 6478,
#  'lower': 5823,
#  'risk': 8127,
#  'division': 3273,
#  'continue': 2561,
#  'account': 775,
#  'double': 3325,
#  'story': 9026,
#  'cover': 2701,
#  'cancel': 1900,
#  'sense': 8466,
#  'book': 1663,
#  'says': 8319,
#  'insure': 5128,
#  'reason': 7755,
#  'traditional': 9583,
#  'conservative': 2497,
#  'eventually': 3708,
#  'reasons': 7760,
#  'dealer': 2900,
#  'interested': 5162,
#  'tough': 9557,
#  'pressure': 7343,
#  'guy': 4525,
#  'room': 8182,
#  'equal': 3642,
#  'monthly': 6267,
#  'payments': 6961,
#  'longer': 5788,
#  'concluded': 2430,
#  'probability': 7396,
#  'auto': 1338,
#  'theft': 9417,
#  'entitled': 3624,
#  'opinion': 6714,
#  'oasys': 6592,
#  'dt': 3389,
#  'navy': 6409,
#  'mil': 6141,
#  'imagination': 4907,
#  'important': 4942,
#  'albert': 956,
#  'einstein': 3498,
#  'idaho': 4860,
#  '26': 315,
#  'turned': 9704,
#  'immediately': 4915,
#  'strictly': 9050,
#  'stayed': 8970,
#  '150': 102,
#  'pickup': 7075,
#  'amazing': 1005,
#  'felt': 3978,
#  'responsible': 8029,
#  '21': 255,
#  'california': 1875,
#  'violation': 10005,
#  '2000': 244,
#  'bargain': 1439,
#  '28': 332,
#  'vw': 10062,
#  'san': 8284,
#  'jose': 5359,
#  'getting': 4347,
#  'vs': 10058,
#  'v6': 9907,
#  '1986': 207,
#  'honda': 4759,
#  'mexico': 6110,
#  'town': 9562,
#  'nearby': 6425,
#  '5x': 539,
#  '2x': 362,
#  'insured': 5129,
#  'robert': 8145,
#  'stack': 8918,
#  'institute': 5113,
#  'transportation': 9621,
#  'studies': 9077,
#  'univ': 9806,
#  'uci': 9740,
#  'mazda': 6015,
#  '37': 417,
#  'saturn': 8308,
#  '64': 558,
#  'st': 8914,
#  ...}

# %% [markdown]
# Индекс, например, для слова car:

# %%
vectorizer.vocabulary_.get('car')
# Out:
# 1923

# %% [markdown]
# А теперь преобразуем строку в вектор:

# %%
text = 'I was wondering if anyone out there could enlighten me on this car I saw'
x = vectorizer.transform([text])

# %% [markdown]
# Какой тип имеет объект, на который указывает x?

# %%
type(x)
# Out:
# scipy.sparse.csr.csr_matrix

# %% [markdown]
# Разреженная матрица!

# %% [markdown]
# # Отступление про разреженные матрицы

# %% [markdown]
# Список ненулевых элементов матрицы:

# %%
x.data
# Out:
# array([1, 1, 1, 1], dtype=int64)

# %% [markdown]
# Индексы строк и столбцов для ненулевых элементов:

# %%
x.nonzero()
# Out:
# (array([0, 0, 0, 0], dtype=int32),
#  array([ 1923,  3609,  8317, 10254], dtype=int32))

# %% [markdown]
# Преобразование к объекту ndarray (именно после приведения к такому виду разреженные матрицы можно подставлять в функции, например, библиотеки Numpy):

# %%
x.toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %% [markdown]
# Вернемся к словарю. Раскодируем вектор x в список слов:

# %%
vectorizer.inverse_transform(x)
# Out:
# [array(['car', 'enlighten', 'saw', 'wondering'], dtype='<U79')]

# %% [markdown]
# Пропало слово I. Но дело в том, что по умолчанию CountVectorizer отбрасывает последовательности, короче 2 символов. На это указывает параметр token_pattern='(?u)\\b\\w\\w+\\b'.

# %% [markdown]
# Переведем весь набор текстов обучающего датасета в набор векторов, получим матрицу X_train:

# %%
X_train = vectorizer.fit_transform(newsgroups_train.data)
X_train.shape
# Out:
# (11314, 10421)

# %% [markdown]
# О пользе разреженных матриц. Отношение числа ненулевых элементов ко всем элементам матрицы X_train:

# %%
X_train.nnz / np.prod(X_train.shape)
# Out:
# 0.004732195804636132

# %% [markdown]
# Задача: запустить модель LDA и Gibbs Sampling с числов тегов 20. Вывести топ-10 слов по каждому тегу. Соотнести полученные теги с тегами из датасета, сделать выводы.

# %%
print(X_train)
# Out:
#   (0, 5889)	1
#   (0, 5792)	1
#   (0, 5048)	1
#   (0, 4719)	1
#   (0, 7423)	1
#   (0, 10373)	1
#   (0, 8851)	1
#   (0, 3593)	1
#   (0, 6227)	1
#   (0, 1645)	1
#   (0, 8030)	1
#   (0, 8480)	1
#   (0, 1808)	1
#   (0, 830)	1
#   (0, 8733)	1
#   (0, 7751)	1
#   (0, 3318)	1
#   (0, 1877)	1
#   (0, 597)	1
#   (0, 3429)	1
#   (0, 546)	1
#   (0, 5563)	1
#   (0, 5791)	1
#   (0, 8888)	1
#   (0, 3317)	1
#   :	:
#   (11313, 1982)	1
#   (11313, 6183)	1
#   (11313, 8898)	1
#   (11313, 9297)	1
#   (11313, 7169)	1
#   (11313, 6190)	1
#   (11313, 1397)	1
#   (11313, 6920)	1
#   (11313, 9010)	1
#   (11313, 8630)	1
#   (11313, 1627)	1
#   (11313, 9574)	1
#   (11313, 10179)	1
#   (11313, 8492)	1
#   (11313, 8504)	1
#   (11313, 4759)	1
#   (11313, 1875)	1
#   (11313, 9703)	1
#   (11313, 363)	1
#   (11313, 4507)	1
#   (11313, 4669)	1
#   (11313, 101)	1
#   (11313, 5756)	1
#   (11313, 6572)	1
#   (11313, 3593)	1

# %%
X_train.data
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
X_train.nonzero()[1]
# Out:
# array([5889, 5792, 5048, ..., 5756, 6572, 3593], dtype=int32)

# %%
from tqdm import tqdm

def LDA(n, X_train, alpha, beta):
    Nkw = np.zeros((n, X_train.shape[1]))
    Ndk = np.zeros((X_train.shape[0], n))
    Nk = np.zeros(n)
    
    doc = X_train.nonzero()[0]
    word = X_train.nonzero()[1]
    z = np.random.choice(n, len(word))
    
    for i in range(len(word)):
        Nkw[z[i]][word[i]]+=1
        Ndk[doc[i]][z[i]]+=1
        Nk[z[i]]+=1
    
    for it in tqdm(range(100)):
        for i in range(len(word)):
            Nkw[z[i]][word[i]]-=1
            Ndk[doc[i]][z[i]]-=1
            Nk[z[i]]-=1
            
            p = (Ndk[doc[i], :] + alpha)*(Nkw[:, word[i]] + beta[word[i]])/(Nk + beta.sum())
            p /= p.sum()
            z[i] = np.random.choice(np.arange(n), p = p)
            
            Nkw[z[i]][word[i]]+=1
            Ndk[doc[i]][z[i]]+=1
            Nk[z[i]]+=1
            
    return z, Nkw, Ndk, Nk

# %%
n = 20
z, Nkw, Ndk, Nk = LDA(n, X_train, 2*np.ones(n), 2*np.ones(len(X_train.nonzero()[1])))
# Out:
# 100%|█████████████████████████████████████| 100/100 [8:02:48<00:00, 288.73s/it]

# %%
N = np.argsort(Nkw)[:, -10:]
N = N[:, ::-1]
top = np.zeros((n,X_train.shape[1]))
for k in range(n):
    for i in N[k]:
        top[k][i]=1
    print('Topic {}:\t{}'.format(k+1, '\t'.join(vectorizer.inverse_transform(top)[k])))
# Out:
# Topic 1:	80ns	birthday	curve	got	michael	omitted	postage	real	shadow	wiretaps
# Topic 2:	ds	listing	minded	nt	recommendations	roms	sticks	tempest	thread	try
# Topic 3:	gee	installing	signal	staying	steep	stuff	unsupported	vhf	weekend	xterm
# Topic 4:	did	edu	going	point	problem	really	sure	using	work	years
# Topic 5:	486	advice	amateur	inherently	lyme	northeast	rob	rubber	sedan	yep
# Topic 6:	ground	inexpensive	isn	lights	modem	nickname	oops	precisely	routine	unless
# Topic 7:	advanced	baud	c7	expensive	granted	lpt1	nhl	proves	terminals	worked
# Topic 8:	astros	cassette	grasp	holes	inform	morals	paranoia	thank	tom	tube
# Topic 9:	1280x1024	april	cabling	commercially	epson	game	hear	hey	popping	resolve
# Topic 10:	advertising	anonymous	bmp	candidate	distributors	openwindows	owner	pcb	requesting	thier
# Topic 11:	ain	berkeley	cbc	chastity	error	headache	loser	lot	obey	shipping
# Topic 12:	400	aspect	buyer	correct	happen	load	macs	rude	sweet	trust
# Topic 13:	approaching	disk	extras	hardly	hi	lite	positioning	prefer	receiver	sale
# Topic 14:	8900c	blame	compatible	derek	dollar	exposed	leaning	loose	netcom	stats
# Topic 15:	autoexec	bmw	church	comment	diagram	forms	friday	lawyers	mail	pinch
# Topic 16:	125	close	diagnosed	experts	hey	memory	mode	oasys	rubber	wibbled
# Topic 17:	40mb	boy	days	experiment	gain	graphics	mozumder	neutral	physician	reward
# Topic 18:	68040	define	diameter	drives	jmd	laserwriter	mail	nickname	panel	rumors
# Topic 19:	audio	civic	floppies	macs	mess	oscillator	sale	sig	standpoint	toshiba
# Topic 20:	500	circa	dip	fail	faster	mercedes	motorola	mustang	regulars	suck
